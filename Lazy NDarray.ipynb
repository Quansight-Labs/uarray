# %%
from uarray import *

# %%
shape = Array.create_shape(Nat(2), Nat(3))

var = Variable("idx_abs")
abstraction = Abstraction(Box(var), Box(None))
a = LazyNDArray.create(Array.create(shape, abstraction))

# %%
replace(a + a)
# Out:
# LazyNDArray(value=Operation(name=<class 'uarray.numpy.lazy_ndarray.LazyNDArray'>, args=(Array(value=Operation(name=<class 'uarray.core.arrays.Array'>, args=(Vec(value=Operation(name=<class 'uarray.core.vectors.Vec'>, args=(Nat(value=2), List(value=Operation(name=<class 'uarray.core.lists.List'>, args=(Nat(value=2), Nat(value=3))), dtype=Nat(value=None)))), dtype=Nat(value=None)), Abstraction(value=Operation(name=<class 'uarray.core.abstractions.Abstraction'>, args=(List(value=Variable(name=None), dtype=Nat(value=None)), Box(value=Operation(name=<ufunc 'add'>, args=(Box(value=Operation(name=<function Abstraction.__call__ at 0x111964840>, args=(Abstraction(value=Box(value=Variable(name='idx_abs')), rettype=Box(value=None)), List(value=Variable(name=None), dtype=Nat(value=None))))), Box(value=Operation(name=<function Abstraction.__call__ at 0x111964840>, args=(Abstraction(value=Box(value=Variable(name='idx_abs')), rettype=Box(value=None)), List(value=Variable(name=None), dtype=Nat(value=None)))))))))), rettype=Box(value=None)))), dtype=Box(value=None)),)))
