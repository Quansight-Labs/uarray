# %%
from uarray import *

# %%
a = create_python_array((2, 2), ((1, 2,), (3, 4)))
a
# Out:
# Array(value=Operation(name='python-array', args=(Box(value=(2, 2)), Box(value=((1, 2), (3, 4))))), dtype=PythonScalar(value=None))

# %%
replace(a[Array.create_idx(Nat(1), Nat(1))])
# Out:
# PythonScalar(value=4)

# %%
v= replace(to_python_array(a))

# %%
a
# Out:
# Array(value=Operation(name='python-array', args=(Box(value=(2, 2)), Box(value=((1, 2), (3, 4))))), dtype=PythonScalar(value=None))

# %%
replace(to_python_array(transpose(a)))
# Out:
# Array(value=Operation(name='python-array', args=(Box(value=(2, 2)), Box(value=((1, 3), (2, 4))))), dtype=PythonScalar(value=None))

# %%
replace(a.idx_abs)
# Out:
# Abstraction(value=Operation(name=<class 'uarray.core.abstractions.Abstraction'>, args=(List(value=Variable(name=None), dtype=Nat(value=None)), PythonScalar(value=Operation(name=<function index_python_array at 0x1090ae8c8>, args=(Array(value=Operation(name='python-array', args=(Box(value=(2, 2)), Box(value=((1, 2), (3, 4))))), dtype=PythonScalar(value=None)), Nat(value=Operation(name=<function List.__getitem__ at 0x10908aae8>, args=(List(value=Variable(name=None), dtype=Nat(value=None)), Nat(value=0)))), Nat(value=Operation(name=<function List.__getitem__ at 0x10908aae8>, args=(List(value=Variable(name=None), dtype=Nat(value=None)), Nat(value=1))))))))), rettype=PythonScalar(value=None))

# %%
from uarray.nested_sequence import PythonScalar

# %%
replace(create_python_bin_abs(lambda l, r: l + r)(PythonScalar(1))(PythonScalar(2)))
# Out:
# PythonScalar(value=3)

# %%
a
# Out:
# Array(value=Operation(name='python-array', args=(Box(value=(2, 2)), Box(value=((1, 2), (3, 4))))), dtype=PythonScalar(value=None))

# %%
replace(to_python_array(binary_operation_abstraction(a, create_python_bin_abs(lambda l, r: l + r), a)))
# Out:
# Array(value=Operation(name='python-array', args=(Box(value=(2, 2)), Box(value=((2, 4), (6, 8))))), dtype=PythonScalar(value=None))
