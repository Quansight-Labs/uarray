# %%
from uarray import *
from uarray.moa import *

# %%
def array_range(n: Nat) -> Array[Nat]:
    def idx_abs(idxs: List[Nat]) -> Nat:
        return idxs[Nat(0)]

    return Array.create(
        shape=Vec.create_infer(n),
        idx_abs=Abstraction.create(idx_abs, List(None, Nat(None))),
    )

# %%
a = array_range(Nat(10))

# %%
replace(MoA.create(a).shape().array.to_list())
# Out:
# List(value=Operation(name=<class 'uarray.core.lists.List'>, args=(Nat(value=10),)), dtype=Nat(value=None))
