# %%
from uarray import *

# %%
v = Vec.create_infer(Nat(1), Nat(2), Nat(3))
v
# Out:
# Vec(value=Operation(name=<class 'uarray.core.vectors.Vec'>, args=(Nat(value=3), List(value=Operation(name=<class 'uarray.core.lists.List'>, args=(Nat(value=1), Nat(value=2), Nat(value=3))), dtype=Nat(value=None)))), dtype=Nat(value=None))

# %%
add_abs = Abstraction.create_bin(lambda a, b: a + b, Nat(object()), Nat(object()))

# %%
replace(add_abs(Nat(1))(Nat(2)))
# Out:
# Nat(value=3)

# %%
replace(inc_(Nat(1)))

# %%
abs(Nat(1))(Nat(2)) + abs(Nat(1))(Nat(2))

# %%
def add_abs(a, b):
    return a + b

reduced = v.reduce(Nat(0), Abstraction.create_bin(add_abs, Nat(object()), Nat(object())))
replace(reduced)
# Out:
# Nat(value=6)

# %%
reduced

# %%
replace_inplace(reduced)
