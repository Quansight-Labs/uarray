# %%
import operator
from uarray import *

# %%
def sum_array(shape: Vec[Nat]):
    """
    Returns an array whose contents are the sum of those indices.
    """

    @Array.create_idx_abs
    def idx_abs(idx: Vec[Nat]) -> Nat:
        return idx.reduce_fn(Nat(0), operator.add)

    return Array.create(shape, idx_abs)

# %%
a = sum_array(Vec.create_infer(Nat(1), Nat(2), Nat(3)))[Array.create_shape(Nat(0), Nat(2), Nat(1))]

# %%
replace(a)
# Out:
# Nat(value=3)

# %%
cb.Build().GetReturnValueShape()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-ea12b5cb9d03> in <module>
# ----> 1 cb.Build().GetReturnValueShape()
#
# /usr/local/miniconda3/envs/uarray/lib/python3.7/site-packages/jaxlib/xla_client.py in Build(self, root, backend)
#     699     else:
#     700       return LocalComputation(
# --> 701           self._client.Build(), is_compiled=False, backend=backend)
#     702
#     703   def SetOpMetadata(self, op_metadata):
#
# /usr/local/miniconda3/envs/uarray/lib/python3.7/site-packages/jaxlib/pywrap_xla.py in Build(self)
#     311
#     312     def Build(self):
# --> 313         return _pywrap_xla.LocalComputationBuilder_Build(self)
#     314
#     315     def BuildWithRoot(self, root):
#
# RuntimeError: Invalid argument: No XlaOp with handle 4472087584
