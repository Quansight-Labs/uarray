# %%
from uarray import *

# %%
a = Bool(True)

# %%
c = a.and_(Bool(False))

# %%
List.create_infer(Nat(1), Nat(1), Nat(2))
# Out:
# List(value=Operation(name=<class 'uarray.core.lists.List'>, args=(Nat(value=1), Nat(value=1), Nat(value=2))), dtype=Nat(value=None))
